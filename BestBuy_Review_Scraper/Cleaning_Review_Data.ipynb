# %% [markdown]
# # Review Cleaner
#
# This is the last step. Usually there are many *.csv* files containing raw review files because Review Scraper may stop or I don't have time to scrape everything at once. In such case I save .csv files with indexed names and then concat everything in this notebook.

# %%
import pandas as pd
import os
import re

# %%
review_files = os.listdir("your_reviews_folder")

# %% [markdown]
# # Raw Files

# %%
## Getting a list with all needed files(paths).

review_files = [("tv_reviews/" + i) for i in review_files]
review_files
# Out:
# ['tv_reviews/tv_reviews_0_17_raw.csv',
#  'tv_reviews/tv_reviews_18_raw.csv',
#  'tv_reviews/tv_reviews_19_22raw.csv',
#  'tv_reviews/tv_reviews_22_24raw.csv',
#  'tv_reviews/tv_reviews_25_28raw.csv',
#  'tv_reviews/tv_reviews_29raw.csv',
#  'tv_reviews/tv_reviews_30_34raw.csv',
#  'tv_reviews/tv_reviews_35_40raw.csv',
#  'tv_reviews/tv_reviews_3raw.csv',
#  'tv_reviews/tv_reviews_41_44raw.csv',
#  'tv_reviews/tv_reviews_45_50raw.csv',
#  'tv_reviews/tv_reviews_51_52raw.csv',
#  'tv_reviews/tv_reviews_53raw.csv',
#  'tv_reviews/tv_reviews_54_56raw.csv',
#  'tv_reviews/tv_reviews_57_62raw.csv',
#  'tv_reviews/tv_reviews_63_67raw.csv',
#  'tv_reviews/tv_reviews_68_77raw.csv']

# %%
## Concataneting all .csv files

all_reviews = pd.concat([pd.read_csv(i) for i in review_files])

# %%
all_reviews
# Out:
#       Rating                                  Title                   Date  \
# 0          5                    Small and powerful!  Nov 22, 2021 11:58 AM
# 1          5                             Good brand   Dec 28, 2019 5:44 PM
# 2          4                 Good TV but not GREAT!   Apr 20, 2021 2:40 PM
# 3          5                                     Tv   Dec 15, 2020 7:12 PM
# 4          5                    great for a bedroom    May 1, 2021 6:03 PM
# ...      ...                                    ...                    ...
# 9724       3               Not getting Dolby Atmos.   Mar 16, 2021 3:06 AM
# 9725       1               Horrible picture quality  Feb 21, 2021 12:38 AM
# 9726       1                          Sharp Picture   Sep 21, 2020 5:21 AM
# 9727       2  Sound drops out. Consider another TV.   Nov 28, 2020 2:43 AM
# 9728       1                        Incorrect Specs   Nov 29, 2020 8:49 PM
#
#      Helpful Unhelpful                                             Review  \
# 0       (20)       (0)  I bought this to have it in my office! and it’...
# 1      (157)      (42)  32 inch Insignia is a good quality tv. Ultra l...
# 2       (24)       (8)  I am 95% happy so far with this tv aside from ...
# 3       (39)       (3)  So far excellent quality and I love all the fe...
# 4       (18)       (5)  I chose to buy the Insignia 32in fire tv for m...
# ...      ...       ...                                                ...
# 9724     (0)       (0)  Received a TV today. Happy with the picture qu...
# 9725     (0)       (1)  I bought this to replace an 8 yr old 52" Samsu...
# 9726     (0)       (7)  The picture on this tv is so sharp and the col...
# 9727     (0)       (0)  Picture looks nice. But the sound frequently d...
# 9728     (0)       (0)  The stand width in the specs is incorrect.  It...
#
#                                            Product_Name  Page
# 0     Insignia™ - 32" Class F20 Series LED HD Smart ...     1
# 1     Insignia™ - 32" Class F20 Series LED HD Smart ...     1
# 2     Insignia™ - 32" Class F20 Series LED HD Smart ...     1
# 3     Insignia™ - 32" Class F20 Series LED HD Smart ...     1
# 4     Insignia™ - 32" Class F20 Series LED HD Smart ...     1
# ...                                                 ...   ...
# 9724  Sony - 55" Class X800H Series LED 4K UHD Smart...    45
# 9725  Sony - 55" Class X800H Series LED 4K UHD Smart...    45
# 9726  Sony - 55" Class X800H Series LED 4K UHD Smart...    45
# 9727  Sony - 55" Class X800H Series LED 4K UHD Smart...    46
# 9728  Sony - 55" Class X800H Series LED 4K UHD Smart...    46
#
# [201623 rows x 8 columns]

# %%
## Droping duplicated rows outright
all_reviews.drop_duplicates(inplace=True)

# %% [markdown]
# **Cheking for thousands separators.**

# %%
all_reviews[all_reviews.Unhelpful.str.len() > 4]
# Out:
#        Rating                                    Title                   Date  \
# 21252       5                Best camera for beginners   Dec 29, 2019 1:12 AM
# 54542       1        Thanks for the terrific Christmas  Dec 25, 2018 10:40 PM
# 59415       2                            Not 50 inches    Nov 6, 2020 9:46 PM
# 18          4  Mounting screws for wall mount too long   Apr 25, 2020 2:00 AM
# 8           1             Kid broke glass with one hit   Jul 10, 2020 4:19 PM
# 3102        1                                 Don' buy   Jun 13, 2021 7:31 PM
#
#       Helpful Unhelpful                                             Review  \
# 21252    (24)     (392)  My son loves the camera, He hasn't put it down...
# 54542    (13)     (101)  Screen was broken, took it out of the box and ...
# 59415     (6)     (110)  It’s says 50inch but we jst measured and it’s ...
# 18       (57)     (131)  I was excited to get this TV.  I had purchased...
# 8        (10)     (232)  I wish you had something to put over the scree...
# 3102     (16)     (137)  OLED55B6P\n\nHorrible burn in. It happen few m...
#
#                                             Product_Name  Page
# 21252  Samsung - 40" Class 5 Series LED Full HD Smart...     2
# 54542  Insignia™ - 55” Class LED 4K UHD Smart Fire TV...     3
# 59415  Insignia™ - 50" Class F30 Series LED 4K UHD Sm...     4
# 18     Samsung - 50" Class 7 Series LED 4K UHD Smart ...     1
# 8      Samsung - 55" Class Q60T Series QLED 4K UHD Sm...     1
# 3102   LG - 55" Class C1 Series OLED 4K UHD Smart web...    28

# %%
## Extracting numbers inside of parantheses

all_reviews["Helpful"] = all_reviews.Helpful.str.extract("\((.+)\)")
all_reviews["Unhelpful"] = all_reviews.Unhelpful.str.extract("\((.+)\)")

# %%
## Parsing number as integers. If there are any exceptions something went wrong
## NA values on titles are OK

all_reviews.astype({"Helpful" : "int64",
                   "Unhelpful" : "int64"}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201583 entries, 0 to 9728
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Rating        201583 non-null  int64
#  1   Title         201544 non-null  object
#  2   Date          201583 non-null  object
#  3   Helpful       201583 non-null  int64
#  4   Unhelpful     201583 non-null  int64
#  5   Review        201583 non-null  object
#  6   Product_Name  201583 non-null  object
#  7   Page          201583 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 13.8+ MB

# %%
all_reviews.reset_index(drop=True,inplace=True)

# %%
## Here I try to examine duplicated reviews. Some products share reviews
## in this case all of them should be removed. Of course this depends on your aim of your project as well.

all_reviews[all_reviews.duplicated(["Review"], keep=False)]
# Out:
#         Rating                                              Title  \
# 319          5                                          Office TV
# 375          5  I really like this product, it does exactly wh...
# 475          5                                  Works great in RV
# 496          5                                           Great tv
# 777          5                                              Great
# ...        ...                                                ...
# 199160       5                                          Great TV!
# 199720       5                                                 TV
# 200252       5                                          Office TV
# 200540       5                                              Great
# 200860       5                                       GREAT SERIES
#
#                          Date Helpful Unhelpful  \
# 319     Jan 29, 2022 10:56 PM       0         0
# 375      Dec 27, 2021 6:21 PM       0         0
# 475      Aug 16, 2021 7:26 PM       0         0
# 496     Dec 29, 2021 10:06 PM       0         0
# 777      Oct 20, 2021 1:49 AM       0         0
# ...                       ...     ...       ...
# 199160   Jun 25, 2021 8:35 PM       0         0
# 199720    Oct 9, 2021 8:11 PM       0         0
# 200252  Jan 29, 2022 10:54 PM       0         0
# 200540   Oct 30, 2021 1:52 AM       0         0
# 200860   Sep 13, 2020 1:11 PM       0         0
#
#                                                    Review  \
# 319     Great Tv  lots of features and great looking c...
# 375     I really like this product, it does exactly wh...
# 475     We bought this TV to replace one in our RV.  I...
# 496     My son loved his new TV. Will definitely recom...
# 777     Great product so far, I really love using them...
# ...                                                   ...
# 199160  Great product for the cost. I would recommend ...
# 199720  Great TV; easy to set up; very satisfied with ...
# 200252  Great Tv  lots of features and great looking c...
# 200540  Can’t settle for less. Picture quality is exce...
# 200860  I wanted to upgrade all the tv's in my house a...
#
#                                              Product_Name  Page
# 319     Insignia™ - 32" Class F20 Series LED HD Smart ...    16
# 375     Insignia™ - 32" Class F20 Series LED HD Smart ...    19
# 475     Insignia™ - 32" Class F20 Series LED HD Smart ...    24
# 496     Insignia™ - 32" Class F20 Series LED HD Smart ...    25
# 777     Insignia™ - 32" Class F20 Series LED HD Smart ...    39
# ...                                                   ...   ...
# 199160  Samsung - 43" Class Q60A Series QLED 4K UHD Sm...    17
# 199720  Samsung - 43" Class Q60A Series QLED 4K UHD Sm...    45
# 200252  Sony - 65" Class X80J Series LED 4K UHD Smart ...    25
# 200540  Sony - 65" Class X80J Series LED 4K UHD Smart ...    39
# 200860  Sony - 55" Class X800H Series LED 4K UHD Smart...     9
#
# [863 rows x 8 columns]

# %%
all_reviews.drop_duplicates(["Review", "Page"], inplace=True)

# %%
all_reviews.drop_duplicates(["Review"], inplace=True)

# %%
## Lastly saving the clean file and checking if everything is right by re-reading it.

all_reviews.to_csv("all_tv_reviews_16_03_22.csv", index = False)

# %%
pd.read_csv("all_tv_reviews_16_03_22.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201113 entries, 0 to 201112
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Rating        201113 non-null  int64
#  1   Title         201074 non-null  object
#  2   Date          201113 non-null  object
#  3   Helpful       201113 non-null  int64
#  4   Unhelpful     201113 non-null  int64
#  5   Review        201113 non-null  object
#  6   Product_Name  201113 non-null  object
#  7   Page          201113 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 12.3+ MB
